# %% [markdown]
# # Audio Sentiment Analysis
#
# The aim of this challenge is to read the audio (.wav) files and classify them into 3 sentiments (Positive, Neutral, or Negative).
#
# Sentiments:-
# - Positive
# - Negative
# - Neutral
#
# We will be applying following Ensemble Algorithms:-
#
# - NN with Tensorflow
#
# # Reading & Understanding Data
# ## Importing Libraries

# %%
import sys, os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import sklearn.metrics as skm
import sklearn.model_selection as skms
import sklearn.preprocessing as skp
import random, os
import librosa, IPython
import librosa.display as lplt
from skimage.io import imread
seed = 12
np.random.seed(seed)

# %% [markdown]
# ### Loading Dataset

# %%
trainPath = '/kaggle/input/audio-speech-sentiment/TRAIN/'
testPath = '/kaggle/input/audio-speech-sentiment/TEST/'
df_base = pd.read_csv('/kaggle/input/audio-speech-sentiment/TRAIN.csv')
df_base.head()
# Out:
#   Filename     Class
# 0  346.wav  Negative
# 1  163.wav   Neutral
# 2  288.wav  Negative
# 3  279.wav  Negative
# 4  244.wav  Negative

# %% [markdown]
# ### About the dataset

# %%
print("Dataset has",df_base.shape[0],"samples")
print("Count of Positive and Negative samples")
df_base['Class'].value_counts().reset_index()
# Out:
# Dataset has 250 samples
# Count of Positive and Negative samples
#       index  Class
# 0  Negative     87
# 1  Positive     82
# 2   Neutral     81

# %%
sample_rate = 44100
def loadAudio(fp):
    return librosa.load(fp, res_type='kaiser_fast', duration=2.5, offset=0.5, sr=sample_rate)

# %% [markdown]
# ### MelSpec -> Array

# %%
def scanFeatures(path, avgFeat=0):
    features = []
    minFeat = sys.maxsize
    maxFeat = 0
    files = sorted(os.listdir(path))
    print("Scanning", path)

    for i, fp in enumerate(files):
        X, sr = loadAudio(os.path.join(path, fp))

        f = librosa.feature.melspectrogram(y=X, sr=sample_rate)
        f = librosa.amplitude_to_db(f, ref=np.max)

        shapeY = f.shape[1]
        if shapeY < minFeat:
            minFeat = shapeY

        if shapeY > maxFeat:
            maxFeat = shapeY

        features.append(f)
    if avgFeat == 0:
        avgFeat = int((minFeat+maxFeat)/2)
    feat_mat = np.zeros((len(files), f.shape[0], avgFeat))
    for i, x in enumerate(features):
        xWidth = min(x.shape[1],avgFeat)
        feat_mat[i, :, :xWidth] = x[:,:xWidth]
    return feat_mat, files

# %%
f_dim = 128
train_data, train_files = scanFeatures(trainPath, f_dim)
test_data, test_files = scanFeatures(testPath, train_data.shape[1])
print(train_data.shape)
print(test_data.shape)
# Out:
# Scanning /kaggle/input/audio-speech-sentiment/TRAIN/
# Scanning /kaggle/input/audio-speech-sentiment/TEST/
# (250, 128, 128)
# (110, 128, 128)

# %% [markdown]
# ### MelSpec -> Images

# %%
def saveImg(f, fp):
    f = np.flip(f, axis=0)
    plt.figure()
    plt.axis('off')
    plt.imsave(fp, f, format='png')
    plt.clf()

# %%
def saveFeatureToImage(path, saveDir, avgFeat=0):
    global sample_rate
    files = sorted(os.listdir(path))
    print("Scanning", path)

    for i, fp in enumerate(files):
        X, sr = loadAudio(os.path.join(path, fp))

        f = librosa.feature.melspectrogram(y=X, sr=sample_rate)
        f = librosa.amplitude_to_db(f, ref=np.max)

        img = np.zeros((f.shape[0], avgFeat))
        xWidth = min(f.shape[1],avgFeat)
        img[:, :xWidth] = f[:,:xWidth]
        fname = os.path.join(saveDir, fp.split('.')[0] + '.png')
        saveImg(img, fname)

# %%
f_dim = 128
train_img_dir = './train_images'
test_img_dir = './test_images'
if not os.path.exists(train_img_dir):
    os.mkdir(train_img_dir)
    saveFeatureToImage(trainPath, train_img_dir, f_dim)
if not os.path.exists(test_img_dir):
    os.mkdir(test_img_dir)
    saveFeatureToImage(testPath, test_img_dir, train_data.shape[1])
# Out:
# Scanning /kaggle/input/audio-speech-sentiment/TRAIN/
# Scanning /kaggle/input/audio-speech-sentiment/TEST/

# %%
def scanImgFeatures(path):
    features = []
    files = sorted(os.listdir(path))
    for x in files:
        fp = os.path.join(path, x)
        img = imread(fp)[:,:,:3]/255.0
        features.append(img)
    return np.array(features), files

# %%
if os.path.exists(train_img_dir):
    train_data_img, train_files_img = scanImgFeatures(train_img_dir)
if os.path.exists(test_img_dir):
    test_data_img, test_files_img = scanImgFeatures(test_img_dir)
    plt.imshow(test_data_img[0])
    plt.show()

# %%
def getPathLabels(p):
    return [df_base[df_base['Filename'] == x].iloc[0,1] for x in p]

# %%
train_labels = getPathLabels(train_files)

# %% [markdown]
# # Data Visualization

# %%
audio_fp = '/kaggle/input/audio-speech-sentiment/TRAIN/1.wav'
audio_data, sr = loadAudio(audio_fp)
audio_data, _ = librosa.effects.trim(audio_data)

# %%
# play sample file
IPython.display.Audio(audio_data, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# plot sample file
plt.figure(figsize=(15,5))
lplt.waveplot(audio_data)
plt.show()

# %%
# Default FFT window size
n_fft = 2048 # window size
hop_length = 512 # window hop length for STFT

stft = librosa.stft(audio_data, n_fft=n_fft, hop_length=hop_length)
stft_db = librosa.amplitude_to_db(stft, ref=np.max)

plt.figure(figsize=(12,4))
lplt.specshow(stft, sr=sr, x_axis='time', y_axis='hz')
plt.colorbar()
plt.title("Spectrogram with amplitude")
plt.show()

plt.figure(figsize=(12,4))
lplt.specshow(stft_db, sr=sr, x_axis='time', y_axis='log', cmap='cool')
plt.colorbar()
plt.title("Spectrogram with decibel log")
plt.show()

# %%
melspec = librosa.feature.melspectrogram(audio_data, sr=sample_rate)
melspec_db = librosa.amplitude_to_db(melspec, ref=np.max)

plt.figure(figsize=(12,4))
lplt.specshow(melspec, sr=sr, x_axis='time', y_axis='hz')
plt.colorbar()
plt.title("Spectrogram with amplitude")
plt.show()

plt.figure(figsize=(12,4))
lplt.specshow(melspec_db, sr=sr, x_axis='time', y_axis='log', cmap='cool')
plt.colorbar()
plt.title("Spectrogram with decibel log")
plt.show()

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Encode Genre Label

# %%
# map labels to index
label_index = dict()
index_label = dict()
for i, x in enumerate(df_base['Class'].unique()):
    label_index[x] = i
    index_label[i] = x
print(label_index)
print(index_label)
# Out:
# {'Negative': 0, 'Neutral': 1, 'Positive': 2}
# {0: 'Negative', 1: 'Neutral', 2: 'Positive'}

# %%
# update labels in df to index
train_labels_idx = [label_index[l] for l in train_labels]
train_labels_idx[::10]
# Out:
# [2, 2, 2, 1, 1, 1, 2, 1, 1, 1, 1, 1, 0, 0, 0, 0, 2, 0, 0, 0, 0, 2, 2, 2, 2]

# %% [markdown]
# # Split Train & Test Sets

# %%
# shuffle samples
df_shuffle = df_base.sample(frac=1, random_state=seed).reset_index(drop=True)

# %%
# remove irrelevant columns
df_shuffle.drop(['Filename'], axis=1, inplace=True)
df_y = df_shuffle.pop('Class')

# split into train dev and test
y_train, y_test = skms.train_test_split(df_y, train_size=0.8, random_state=seed, stratify=df_y)

# %%
print(f"Train set has {y_train.shape[0]} records out of {len(df_shuffle)} which is {round(y_train.shape[0]/len(df_shuffle)*100)}%")
print(f"Test set has {y_test.shape[0]} records out of {len(df_shuffle)} which is {round(y_test.shape[0]/len(df_shuffle)*100)}%")
# Out:
# Train set has 200 records out of 250 which is 80%
# Test set has 50 records out of 250 which is 20%

# %%
# stratified split check
print(y_train.value_counts())
print(y_test.value_counts())
# Out:
# Negative    70
# Neutral     65
# Positive    65
# Name: Class, dtype: int64
# Negative    17
# Positive    17
# Neutral     16
# Name: Class, dtype: int64

# %%
# divide train_data into X_train and X_test
X_train = train_data[y_train.index.tolist(), :, :]
X_test = train_data[y_test.index.tolist(), :, :]
X_test.shape
# Out:
# (50, 128, 128)

# %%
# divide train_data_img into X_train_img and X_test_img
X_train_img = train_data_img[y_train.index.tolist(), :, :]
X_test_img = train_data_img[y_test.index.tolist(), :, :]
X_test_img.shape
# Out:
# (50, 128, 128, 3)

# %%
y_train = np.array([train_labels_idx[x] for x in y_train.index.tolist()])
y_test = np.array([train_labels_idx[x] for x in y_test.index.tolist()])
y_train[::10]
# Out:
# array([1, 0, 0, 0, 0, 1, 2, 1, 1, 0, 2, 0, 1, 0, 0, 1, 1, 2, 2, 1])

# %% [markdown]
# ## Scale the Features

# %%
# scale features
scaler = skp.MinMaxScaler()
X_train = scaler.fit_transform(X_train.reshape(-1, X_train.shape[-1])).reshape(X_train.shape)
X_test = scaler.transform(X_test.reshape(-1, X_test.shape[-1])).reshape(X_test.shape)
test_data = scaler.transform(test_data.reshape(-1, test_data.shape[-1])).reshape(test_data.shape)
print(X_train.shape)
# Out:
# (200, 128, 128)

# %% [markdown]
# # Model Building

# %%
import tensorflow as tf
print("TF version:-", tf.__version__)
import keras as k
from keras import backend as K
tf.random.set_seed(seed)
# Out:
# TF version:- 2.3.1

# %%
bestModelPath = './best_model.hdf5'
ACCURACY_THRESHOLD = 0.98

class myCallback(k.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get('val_accuracy') > ACCURACY_THRESHOLD):
            print("\n\nStopping training as we have reached %2.2f%% accuracy!" %(ACCURACY_THRESHOLD*100))   
            self.model.stop_training = True

acc_callback = myCallback()


def trainModel(model, epochs, optimizer, vb=1):
    cbs = [#k.callbacks.ReduceLROnPlateau(patience=5, verbose=1), 
           k.callbacks.ModelCheckpoint(filepath=bestModelPath, monitor='val_loss', verbose=1, save_best_only=True)]
    batch_size = 64
    callback = myCallback()
    model.compile(optimizer=optimizer,
                  loss='sparse_categorical_crossentropy',
                  metrics='accuracy'
    )
    return model.fit(X_train, y_train, 
#                      validation_data=(X_test, y_test), 
                     epochs=epochs, verbose=vb,
                     validation_split=0.2,
                     batch_size=batch_size, callbacks=cbs)

def plotHistory(history):
    print("Max. Validation Accuracy",max(history.history["val_accuracy"]))
    pd.DataFrame(history.history).plot(figsize=(12,6))
    plt.show()

# %%
model_1 = k.models.Sequential([
    k.layers.Conv1D(256, 8, padding='same', activation='relu', input_shape=(X_train.shape[1], X_train.shape[2])),
#     k.layers.Conv1D(256, 8, padding='same', activation='relu'),
    k.layers.BatchNormalization(),
    k.layers.Dropout(0.2),
    k.layers.MaxPooling1D(pool_size=(8)),
    k.layers.Conv1D(128, 8, padding='same', activation='relu'),
#     k.layers.Conv1D(128, 8, padding='same', activation='relu'),
#     k.layers.Conv1D(128, 8, padding='same', activation='relu'),
    k.layers.BatchNormalization(),
    k.layers.Dropout(0.2),
    k.layers.MaxPooling1D(pool_size=(5)),
#     k.layers.Conv1D(64, 8, padding='same', activation='relu'),
    k.layers.Conv1D(64, 8, padding='same', activation='relu'),
    k.layers.BatchNormalization(),
    k.layers.Flatten(),
#     k.layers.Dense(64, activation='relu'),
    k.layers.Dense(len(index_label), activation='softmax'),
])
print(model_1.summary())
model_1_history = trainModel(model=model_1, epochs=50, optimizer='adam', vb=0)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 128, 256)          262400
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128, 256)          1024
# _________________________________________________________________
# dropout (Dropout)            (None, 128, 256)          0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 16, 256)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 16, 128)           262272
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16, 128)           512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 128)           0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 3, 128)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 3, 64)             65600
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 3, 64)             256
# _________________________________________________________________
# flatten (Flatten)            (None, 192)               0
# _________________________________________________________________
# dense (Dense)                (None, 3)                 579
# =================================================================
# Total params: 592,643
# Trainable params: 591,747
# Non-trainable params: 896
# _________________________________________________________________
# None
#
# Epoch 00001: val_loss improved from inf to 1.09181, saving model to ./best_model.hdf5
#
# Epoch 00002: val_loss improved from 1.09181 to 1.06980, saving model to ./best_model.hdf5
#
# Epoch 00003: val_loss did not improve from 1.06980
#
# Epoch 00004: val_loss did not improve from 1.06980
#
# Epoch 00005: val_loss improved from 1.06980 to 1.06534, saving model to ./best_model.hdf5
#
# Epoch 00006: val_loss improved from 1.06534 to 1.01215, saving model to ./best_model.hdf5
#
# Epoch 00007: val_loss improved from 1.01215 to 0.98836, saving model to ./best_model.hdf5
#
# Epoch 00008: val_loss improved from 0.98836 to 0.93997, saving model to ./best_model.hdf5
#
# Epoch 00009: val_loss improved from 0.93997 to 0.88359, saving model to ./best_model.hdf5
#
# Epoch 00010: val_loss improved from 0.88359 to 0.83468, saving model to ./best_model.hdf5
#
# Epoch 00011: val_loss improved from 0.83468 to 0.79529, saving model to ./best_model.hdf5
#
# Epoch 00012: val_loss improved from 0.79529 to 0.77379, saving model to ./best_model.hdf5
#
# Epoch 00013: val_loss improved from 0.77379 to 0.76204, saving model to ./best_model.hdf5
#
# Epoch 00014: val_loss did not improve from 0.76204
#
# Epoch 00015: val_loss did not improve from 0.76204
#
# Epoch 00016: val_loss did not improve from 0.76204
#
# Epoch 00017: val_loss did not improve from 0.76204
#
# Epoch 00018: val_loss did not improve from 0.76204
#
# Epoch 00019: val_loss did not improve from 0.76204
#
# Epoch 00020: val_loss did not improve from 0.76204
#
# Epoch 00021: val_loss did not improve from 0.76204
#
# Epoch 00022: val_loss did not improve from 0.76204
#
# Epoch 00023: val_loss did not improve from 0.76204
#
# Epoch 00024: val_loss did not improve from 0.76204
#
# Epoch 00025: val_loss did not improve from 0.76204
#
# Epoch 00026: val_loss did not improve from 0.76204
#
# Epoch 00027: val_loss did not improve from 0.76204
#
# Epoch 00028: val_loss did not improve from 0.76204
#
# Epoch 00029: val_loss did not improve from 0.76204
#
# Epoch 00030: val_loss did not improve from 0.76204
#
# Epoch 00031: val_loss did not improve from 0.76204
#
# Epoch 00032: val_loss did not improve from 0.76204
#
# Epoch 00033: val_loss did not improve from 0.76204
#
# Epoch 00034: val_loss did not improve from 0.76204
#
# Epoch 00035: val_loss did not improve from 0.76204
#
# Epoch 00036: val_loss did not improve from 0.76204
#
# Epoch 00037: val_loss did not improve from 0.76204
#
# Epoch 00038: val_loss did not improve from 0.76204
#
# Epoch 00039: val_loss did not improve from 0.76204
#
# Epoch 00040: val_loss did not improve from 0.76204
#
# Epoch 00041: val_loss did not improve from 0.76204
#
# Epoch 00042: val_loss did not improve from 0.76204
#
# Epoch 00043: val_loss did not improve from 0.76204
#
# Epoch 00044: val_loss did not improve from 0.76204
#
# Epoch 00045: val_loss did not improve from 0.76204
#
# Epoch 00046: val_loss did not improve from 0.76204
#
# Epoch 00047: val_loss did not improve from 0.76204
#
# Epoch 00048: val_loss did not improve from 0.76204
#
# Epoch 00049: val_loss did not improve from 0.76204
#
# Epoch 00050: val_loss did not improve from 0.76204

# %%
plotHistory(model_1_history)
# Out:
# Max. Validation Accuracy 0.75

# %%
# evaluation
test_loss, test_acc  = k.models.load_model(bestModelPath).evaluate(X_test, y_test, batch_size=128)
print("The test Loss is :",test_loss)
print("The test Accuracy is :",test_acc*100)
# Out:
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7489 - accuracy: 0.2200
# The test Loss is : 0.748944103717804
# The test Accuracy is : 21.99999988079071

# %%
model_2 = k.models.Sequential([
    k.layers.Conv1D(256, 5, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2])),
    k.layers.BatchNormalization(),
    k.layers.Dropout(0.3),
    k.layers.MaxPooling1D(pool_size=(2)),
    k.layers.Conv1D(128, 3, activation='relu'),
    k.layers.BatchNormalization(),
    k.layers.Dropout(0.3),
    k.layers.MaxPooling1D(pool_size=(3)),
    k.layers.Conv1D(64, 3, activation='relu'),
    k.layers.BatchNormalization(),
    k.layers.Flatten(),
    k.layers.Dense(32, activation='relu'),
    k.layers.Dense(len(index_label), activation='softmax'),
])
print(model_2.summary())
model_2_history = trainModel(model=model_2, epochs=100, optimizer='adam', vb=0)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_3 (Conv1D)            (None, 124, 256)          164096
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 124, 256)          1024
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 124, 256)          0
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 62, 256)           0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 60, 128)           98432
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 60, 128)           512
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 60, 128)           0
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 20, 128)           0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 18, 64)            24640
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 18, 64)            256
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1152)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                36896
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 99
# =================================================================
# Total params: 325,955
# Trainable params: 325,059
# Non-trainable params: 896
# _________________________________________________________________
# None
#
# Epoch 00001: val_loss improved from inf to 1.07000, saving model to ./best_model.hdf5
#
# Epoch 00002: val_loss improved from 1.07000 to 1.05745, saving model to ./best_model.hdf5
#
# Epoch 00003: val_loss improved from 1.05745 to 1.02890, saving model to ./best_model.hdf5
#
# Epoch 00004: val_loss improved from 1.02890 to 1.02072, saving model to ./best_model.hdf5
#
# Epoch 00005: val_loss improved from 1.02072 to 1.01696, saving model to ./best_model.hdf5
#
# Epoch 00006: val_loss improved from 1.01696 to 1.00442, saving model to ./best_model.hdf5
#
# Epoch 00007: val_loss improved from 1.00442 to 0.99059, saving model to ./best_model.hdf5
#
# Epoch 00008: val_loss improved from 0.99059 to 0.98677, saving model to ./best_model.hdf5
#
# Epoch 00009: val_loss did not improve from 0.98677
#
# Epoch 00010: val_loss did not improve from 0.98677
#
# Epoch 00011: val_loss did not improve from 0.98677
#
# Epoch 00012: val_loss did not improve from 0.98677
#
# Epoch 00013: val_loss did not improve from 0.98677
#
# Epoch 00014: val_loss did not improve from 0.98677
#
# Epoch 00015: val_loss did not improve from 0.98677
#
# Epoch 00016: val_loss did not improve from 0.98677
#
# Epoch 00017: val_loss did not improve from 0.98677
#
# Epoch 00018: val_loss did not improve from 0.98677
#
# Epoch 00019: val_loss did not improve from 0.98677
#
# Epoch 00020: val_loss did not improve from 0.98677
#
# Epoch 00021: val_loss did not improve from 0.98677
#
# Epoch 00022: val_loss did not improve from 0.98677
#
# Epoch 00023: val_loss did not improve from 0.98677
#
# Epoch 00024: val_loss did not improve from 0.98677
#
# Epoch 00025: val_loss did not improve from 0.98677
#
# Epoch 00026: val_loss did not improve from 0.98677
#
# Epoch 00027: val_loss did not improve from 0.98677
#
# Epoch 00028: val_loss did not improve from 0.98677
#
# Epoch 00029: val_loss did not improve from 0.98677
#
# Epoch 00030: val_loss did not improve from 0.98677
#
# Epoch 00031: val_loss did not improve from 0.98677
#
# Epoch 00032: val_loss did not improve from 0.98677
#
# Epoch 00033: val_loss did not improve from 0.98677
#
# Epoch 00034: val_loss did not improve from 0.98677
#
# Epoch 00035: val_loss did not improve from 0.98677
#
# Epoch 00036: val_loss did not improve from 0.98677
#
# Epoch 00037: val_loss did not improve from 0.98677
#
# Epoch 00038: val_loss did not improve from 0.98677
#
# Epoch 00039: val_loss did not improve from 0.98677
#
# Epoch 00040: val_loss did not improve from 0.98677
#
# Epoch 00041: val_loss did not improve from 0.98677
#
# Epoch 00042: val_loss did not improve from 0.98677
#
# Epoch 00043: val_loss did not improve from 0.98677
#
# Epoch 00044: val_loss did not improve from 0.98677
#
# Epoch 00045: val_loss did not improve from 0.98677
#
# Epoch 00046: val_loss did not improve from 0.98677
#
# Epoch 00047: val_loss did not improve from 0.98677
#
# Epoch 00048: val_loss did not improve from 0.98677
#
# Epoch 00049: val_loss did not improve from 0.98677
#
# Epoch 00050: val_loss did not improve from 0.98677
#
# Epoch 00051: val_loss did not improve from 0.98677
#
# Epoch 00052: val_loss did not improve from 0.98677
#
# Epoch 00053: val_loss did not improve from 0.98677
#
# Epoch 00054: val_loss did not improve from 0.98677
#
# Epoch 00055: val_loss did not improve from 0.98677
#
# Epoch 00056: val_loss did not improve from 0.98677
#
# Epoch 00057: val_loss did not improve from 0.98677
#
# Epoch 00058: val_loss did not improve from 0.98677
#
# Epoch 00059: val_loss did not improve from 0.98677
#
# Epoch 00060: val_loss did not improve from 0.98677
#
# Epoch 00061: val_loss did not improve from 0.98677
#
# Epoch 00062: val_loss did not improve from 0.98677
#
# Epoch 00063: val_loss did not improve from 0.98677
#
# Epoch 00064: val_loss did not improve from 0.98677
#
# Epoch 00065: val_loss did not improve from 0.98677
#
# Epoch 00066: val_loss did not improve from 0.98677
#
# Epoch 00067: val_loss did not improve from 0.98677
#
# Epoch 00068: val_loss did not improve from 0.98677
#
# Epoch 00069: val_loss did not improve from 0.98677
#
# Epoch 00070: val_loss did not improve from 0.98677
#
# Epoch 00071: val_loss did not improve from 0.98677
#
# Epoch 00072: val_loss did not improve from 0.98677
#
# Epoch 00073: val_loss did not improve from 0.98677
#
# Epoch 00074: val_loss did not improve from 0.98677
#
# Epoch 00075: val_loss did not improve from 0.98677
#
# Epoch 00076: val_loss did not improve from 0.98677
#
# Epoch 00077: val_loss did not improve from 0.98677
#
# Epoch 00078: val_loss did not improve from 0.98677
#
# Epoch 00079: val_loss did not improve from 0.98677
#
# Epoch 00080: val_loss did not improve from 0.98677
#
# Epoch 00081: val_loss did not improve from 0.98677
#
# Epoch 00082: val_loss did not improve from 0.98677
#
# Epoch 00083: val_loss did not improve from 0.98677
#
# Epoch 00084: val_loss did not improve from 0.98677
#
# Epoch 00085: val_loss did not improve from 0.98677
#
# Epoch 00086: val_loss did not improve from 0.98677
#
# Epoch 00087: val_loss did not improve from 0.98677
#
# Epoch 00088: val_loss did not improve from 0.98677
#
# Epoch 00089: val_loss did not improve from 0.98677
#
# Epoch 00090: val_loss did not improve from 0.98677
#
# Epoch 00091: val_loss did not improve from 0.98677
#
# Epoch 00092: val_loss did not improve from 0.98677
#
# Epoch 00093: val_loss did not improve from 0.98677
#
# Epoch 00094: val_loss did not improve from 0.98677
#
# Epoch 00095: val_loss did not improve from 0.98677
#
# Epoch 00096: val_loss did not improve from 0.98677
#
# Epoch 00097: val_loss did not improve from 0.98677
#
# Epoch 00098: val_loss did not improve from 0.98677
#
# Epoch 00099: val_loss did not improve from 0.98677
#
# Epoch 00100: val_loss did not improve from 0.98677

# %%
plotHistory(model_2_history)
# Out:
# Max. Validation Accuracy 0.7749999761581421

# %%
# evaluation
test_loss, test_acc  = k.models.load_model(bestModelPath).evaluate(X_test, y_test, batch_size=128)
print("The test Loss is :",test_loss)
print("The test Accuracy is :",test_acc*100)
# Out:
# 1/1 [==============================] - 0s 1ms/step - loss: 0.9612 - accuracy: 0.2600
# The test Loss is : 0.961239218711853
# The test Accuracy is : 25.999999046325684

# %%
model_3 = k.models.Sequential([
    k.layers.Bidirectional(k.layers.LSTM(256, return_sequences=True), input_shape=(X_train.shape[1], X_train.shape[2])),

    k.layers.Bidirectional(k.layers.LSTM(128, return_sequences=False)),

    k.layers.Dense(64, activation='relu'),
    k.layers.Dropout(0.2),
    k.layers.Dense(64, activation='relu'),
    k.layers.Dropout(0.2),
    k.layers.Dense(32, activation='relu'),
    k.layers.Dense(len(index_label), activation='softmax'),
])
print(model_3.summary())
model_3_history = trainModel(model=model_3, epochs=100, optimizer='rmsprop', vb=0)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional (Bidirectional (None, 128, 512)          788480
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 256)               656384
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_6 (Dense)              (None, 3)                 99
# =================================================================
# Total params: 1,467,651
# Trainable params: 1,467,651
# Non-trainable params: 0
# _________________________________________________________________
# None
#
# Epoch 00001: val_loss improved from inf to 1.10776, saving model to ./best_model.hdf5
#
# Epoch 00002: val_loss improved from 1.10776 to 1.05985, saving model to ./best_model.hdf5
#
# Epoch 00003: val_loss improved from 1.05985 to 1.05412, saving model to ./best_model.hdf5
#
# Epoch 00004: val_loss did not improve from 1.05412
#
# Epoch 00005: val_loss improved from 1.05412 to 1.02737, saving model to ./best_model.hdf5
#
# Epoch 00006: val_loss did not improve from 1.02737
#
# Epoch 00007: val_loss improved from 1.02737 to 0.85803, saving model to ./best_model.hdf5
#
# Epoch 00008: val_loss did not improve from 0.85803
#
# Epoch 00009: val_loss did not improve from 0.85803
#
# Epoch 00010: val_loss did not improve from 0.85803
#
# Epoch 00011: val_loss did not improve from 0.85803
#
# Epoch 00012: val_loss did not improve from 0.85803
#
# Epoch 00013: val_loss did not improve from 0.85803
#
# Epoch 00014: val_loss did not improve from 0.85803
#
# Epoch 00015: val_loss did not improve from 0.85803
#
# Epoch 00016: val_loss improved from 0.85803 to 0.66771, saving model to ./best_model.hdf5
#
# Epoch 00017: val_loss did not improve from 0.66771
#
# Epoch 00018: val_loss improved from 0.66771 to 0.60407, saving model to ./best_model.hdf5
#
# Epoch 00019: val_loss did not improve from 0.60407
#
# Epoch 00020: val_loss did not improve from 0.60407
#
# Epoch 00021: val_loss did not improve from 0.60407
#
# Epoch 00022: val_loss did not improve from 0.60407
#
# Epoch 00023: val_loss did not improve from 0.60407
#
# Epoch 00024: val_loss improved from 0.60407 to 0.54790, saving model to ./best_model.hdf5
#
# Epoch 00025: val_loss did not improve from 0.54790
#
# Epoch 00026: val_loss did not improve from 0.54790
#
# Epoch 00027: val_loss did not improve from 0.54790
#
# Epoch 00028: val_loss improved from 0.54790 to 0.54764, saving model to ./best_model.hdf5
#
# Epoch 00029: val_loss improved from 0.54764 to 0.46304, saving model to ./best_model.hdf5
#
# Epoch 00030: val_loss did not improve from 0.46304
#
# Epoch 00031: val_loss did not improve from 0.46304
#
# Epoch 00032: val_loss did not improve from 0.46304
#
# Epoch 00033: val_loss did not improve from 0.46304
#
# Epoch 00034: val_loss did not improve from 0.46304
#
# Epoch 00035: val_loss did not improve from 0.46304
#
# Epoch 00036: val_loss did not improve from 0.46304
#
# Epoch 00037: val_loss improved from 0.46304 to 0.36576, saving model to ./best_model.hdf5
#
# Epoch 00038: val_loss did not improve from 0.36576
#
# Epoch 00039: val_loss did not improve from 0.36576
#
# Epoch 00040: val_loss did not improve from 0.36576
#
# Epoch 00041: val_loss did not improve from 0.36576
#
# Epoch 00042: val_loss did not improve from 0.36576
#
# Epoch 00043: val_loss did not improve from 0.36576
#
# Epoch 00044: val_loss did not improve from 0.36576
#
# Epoch 00045: val_loss did not improve from 0.36576
#
# Epoch 00046: val_loss did not improve from 0.36576
#
# Epoch 00047: val_loss did not improve from 0.36576
#
# Epoch 00048: val_loss did not improve from 0.36576
#
# Epoch 00049: val_loss did not improve from 0.36576
#
# Epoch 00050: val_loss did not improve from 0.36576
#
# Epoch 00051: val_loss did not improve from 0.36576
#
# Epoch 00052: val_loss did not improve from 0.36576
#
# Epoch 00053: val_loss did not improve from 0.36576
#
# Epoch 00054: val_loss did not improve from 0.36576
#
# Epoch 00055: val_loss did not improve from 0.36576
#
# Epoch 00056: val_loss did not improve from 0.36576
#
# Epoch 00057: val_loss did not improve from 0.36576
#
# Epoch 00058: val_loss did not improve from 0.36576
#
# Epoch 00059: val_loss did not improve from 0.36576
#
# Epoch 00060: val_loss did not improve from 0.36576
#
# Epoch 00061: val_loss did not improve from 0.36576
#
# Epoch 00062: val_loss did not improve from 0.36576
#
# Epoch 00063: val_loss did not improve from 0.36576
#
# Epoch 00064: val_loss did not improve from 0.36576
#
# Epoch 00065: val_loss did not improve from 0.36576
#
# Epoch 00066: val_loss did not improve from 0.36576
#
# Epoch 00067: val_loss did not improve from 0.36576
#
# Epoch 00068: val_loss did not improve from 0.36576
#
# Epoch 00069: val_loss did not improve from 0.36576
#
# Epoch 00070: val_loss did not improve from 0.36576
#
# Epoch 00071: val_loss did not improve from 0.36576
#
# Epoch 00072: val_loss did not improve from 0.36576
#
# Epoch 00073: val_loss did not improve from 0.36576
#
# Epoch 00074: val_loss did not improve from 0.36576
#
# Epoch 00075: val_loss did not improve from 0.36576
#
# Epoch 00076: val_loss did not improve from 0.36576
#
# Epoch 00077: val_loss did not improve from 0.36576
#
# Epoch 00078: val_loss did not improve from 0.36576
#
# Epoch 00079: val_loss did not improve from 0.36576
#
# Epoch 00080: val_loss did not improve from 0.36576
#
# Epoch 00081: val_loss did not improve from 0.36576
#
# Epoch 00082: val_loss did not improve from 0.36576
#
# Epoch 00083: val_loss did not improve from 0.36576
#
# Epoch 00084: val_loss did not improve from 0.36576
#
# Epoch 00085: val_loss did not improve from 0.36576
#
# Epoch 00086: val_loss did not improve from 0.36576
#
# Epoch 00087: val_loss did not improve from 0.36576
#
# Epoch 00088: val_loss did not improve from 0.36576
#
# Epoch 00089: val_loss did not improve from 0.36576
#
# Epoch 00090: val_loss did not improve from 0.36576
#
# Epoch 00091: val_loss did not improve from 0.36576
#
# Epoch 00092: val_loss did not improve from 0.36576
#
# Epoch 00093: val_loss did not improve from 0.36576
#
# Epoch 00094: val_loss did not improve from 0.36576
#
# Epoch 00095: val_loss did not improve from 0.36576
#
# Epoch 00096: val_loss did not improve from 0.36576
#
# Epoch 00097: val_loss did not improve from 0.36576
#
# Epoch 00098: val_loss did not improve from 0.36576
#
# Epoch 00099: val_loss did not improve from 0.36576
#
# Epoch 00100: val_loss did not improve from 0.36576

# %%
plotHistory(model_3_history)
# Out:
# Max. Validation Accuracy 0.8999999761581421

# %%
# evaluation
test_loss, test_acc  = k.models.load_model(bestModelPath).evaluate(X_test, y_test, batch_size=128)
print("The test Loss is :",test_loss)
print("The test Accuracy is :",test_acc*100)
# Out:
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5566 - accuracy: 0.3000
# The test Loss is : 0.5566480159759521
# The test Accuracy is : 30.000001192092896

# %%
# make features 3D with last dim as 1 for 1DConv
X_train = np.expand_dims(X_train, axis=3)
X_test = np.expand_dims(X_test, axis=3)
X_train.shape
# Out:
# (200, 128, 128, 1)

# %%
model_4 = k.models.Sequential([
    k.layers.Conv2D(256, (5,5), activation='relu', input_shape=(X_train.shape[1], X_train.shape[2], 1)),
    k.layers.BatchNormalization(),
    k.layers.MaxPooling2D(pool_size=(2)),
    k.layers.Dropout(0.3),
    k.layers.Conv2D(128, (3,3), activation='relu'),
    k.layers.BatchNormalization(),
    k.layers.MaxPooling2D(pool_size=(2)),
    k.layers.Dropout(0.3),
    k.layers.Conv2D(64, (3,3), padding='valid', activation='relu'),
    k.layers.BatchNormalization(),
    k.layers.Flatten(),
    k.layers.Dense(64, activation='relu'),
    k.layers.Dense(len(index_label), activation='softmax'),

])
print(model_4.summary())
model_4_history = trainModel(model=model_4, epochs=50, optimizer='adam', vb=0)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 124, 124, 256)     6656
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 124, 124, 256)     1024
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 62, 62, 256)       0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 62, 62, 256)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 60, 60, 128)       295040
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 60, 60, 128)       512
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 30, 30, 128)       0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 30, 30, 128)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 28, 28, 64)        73792
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 28, 28, 64)        256
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 50176)             0
# _________________________________________________________________
# dense_9 (Dense)              (None, 64)                3211328
# _________________________________________________________________
# dense_10 (Dense)             (None, 3)                 195
# =================================================================
# Total params: 3,588,803
# Trainable params: 3,587,907
# Non-trainable params: 896
# _________________________________________________________________
# None
#
# Epoch 00001: val_loss improved from inf to 1.16774, saving model to ./best_model.hdf5
#
# Epoch 00002: val_loss did not improve from 1.16774
#
# Epoch 00003: val_loss did not improve from 1.16774
#
# Epoch 00004: val_loss improved from 1.16774 to 1.12543, saving model to ./best_model.hdf5
#
# Epoch 00005: val_loss did not improve from 1.12543
#
# Epoch 00006: val_loss did not improve from 1.12543
#
# Epoch 00007: val_loss did not improve from 1.12543
#
# Epoch 00008: val_loss did not improve from 1.12543
#
# Epoch 00009: val_loss did not improve from 1.12543
#
# Epoch 00010: val_loss did not improve from 1.12543
#
# Epoch 00011: val_loss did not improve from 1.12543
#
# Epoch 00012: val_loss did not improve from 1.12543
#
# Epoch 00013: val_loss did not improve from 1.12543
#
# Epoch 00014: val_loss did not improve from 1.12543
#
# Epoch 00015: val_loss did not improve from 1.12543
#
# Epoch 00016: val_loss did not improve from 1.12543
#
# Epoch 00017: val_loss did not improve from 1.12543
#
# Epoch 00018: val_loss did not improve from 1.12543
#
# Epoch 00019: val_loss did not improve from 1.12543
#
# Epoch 00020: val_loss did not improve from 1.12543
#
# Epoch 00021: val_loss did not improve from 1.12543
#
# Epoch 00022: val_loss did not improve from 1.12543
#
# Epoch 00023: val_loss did not improve from 1.12543
#
# Epoch 00024: val_loss did not improve from 1.12543
#
# Epoch 00025: val_loss did not improve from 1.12543
#
# Epoch 00026: val_loss did not improve from 1.12543
#
# Epoch 00027: val_loss did not improve from 1.12543
#
# Epoch 00028: val_loss did not improve from 1.12543
#
# Epoch 00029: val_loss did not improve from 1.12543
#
# Epoch 00030: val_loss did not improve from 1.12543
#
# Epoch 00031: val_loss did not improve from 1.12543
#
# Epoch 00032: val_loss did not improve from 1.12543
#
# Epoch 00033: val_loss did not improve from 1.12543
#
# Epoch 00034: val_loss did not improve from 1.12543
#
# Epoch 00035: val_loss did not improve from 1.12543
#
# Epoch 00036: val_loss did not improve from 1.12543
#
# Epoch 00037: val_loss did not improve from 1.12543
#
# Epoch 00038: val_loss did not improve from 1.12543
#
# Epoch 00039: val_loss did not improve from 1.12543
#
# Epoch 00040: val_loss did not improve from 1.12543
#
# Epoch 00041: val_loss did not improve from 1.12543
#
# Epoch 00042: val_loss did not improve from 1.12543
#
# Epoch 00043: val_loss did not improve from 1.12543
#
# Epoch 00044: val_loss did not improve from 1.12543
#
# Epoch 00045: val_loss did not improve from 1.12543
#
# Epoch 00046: val_loss did not improve from 1.12543
#
# Epoch 00047: val_loss did not improve from 1.12543
#
# Epoch 00048: val_loss did not improve from 1.12543
#
# Epoch 00049: val_loss did not improve from 1.12543
#
# Epoch 00050: val_loss did not improve from 1.12543

# %%
plotHistory(model_4_history)
# Out:
# Max. Validation Accuracy 0.699999988079071

# %%
# evaluation
test_loss, test_acc  = k.models.load_model(bestModelPath).evaluate(X_test, y_test, batch_size=128)
print("The test Loss is :",test_loss)
print("The test Accuracy is :",test_acc*100)
# Out:
# 1/1 [==============================] - 0s 2ms/step - loss: 1.3606 - accuracy: 0.0000e+00
# The test Loss is : 1.3605525493621826
# The test Accuracy is : 0.0

# %%
inputShape = (X_train.shape[1], X_train.shape[2], 1)
model_5 = k.models.Sequential([
    k.layers.TimeDistributed(k.layers.Conv1D(256, 5), input_shape=inputShape),
    k.layers.TimeDistributed(k.layers.BatchNormalization()),
    k.layers.TimeDistributed(k.layers.MaxPooling1D((2))),
    k.layers.TimeDistributed(k.layers.Dropout(0.3)),

    k.layers.TimeDistributed(k.layers.Conv1D(128, 3), input_shape=inputShape),
    k.layers.TimeDistributed(k.layers.BatchNormalization()),
    k.layers.TimeDistributed(k.layers.MaxPooling1D((2))),
    k.layers.TimeDistributed(k.layers.Dropout(0.3)),
    k.layers.TimeDistributed(k.layers.Flatten())

], name="conv_3d7")

model_5.add(k.layers.Bidirectional(k.layers.LSTM(256, return_sequences=True)))
model_5.add(k.layers.Dropout(0.3))

model_5.add(k.layers.Bidirectional(k.layers.LSTM(128)))
model_5.add(k.layers.Dropout(0.3))

model_5.add(k.layers.Dense(64, activation='relu'))
model_5.add(k.layers.Dropout(0.3))

model_5.add(k.layers.Dense(len(index_label), activation='softmax'))

print(model_5.summary())
model_5_history = trainModel(model=model_5, epochs=100, optimizer='adam', vb=0)
# Out:
# Model: "conv_3d7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed (TimeDistri (None, 128, 124, 256)     1536
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 128, 124, 256)     1024
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 128, 62, 256)      0
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, 128, 62, 256)      0
# _________________________________________________________________
# time_distributed_4 (TimeDist (None, 128, 60, 128)      98432
# _________________________________________________________________
# time_distributed_5 (TimeDist (None, 128, 60, 128)      512
# _________________________________________________________________
# time_distributed_6 (TimeDist (None, 128, 30, 128)      0
# _________________________________________________________________
# time_distributed_7 (TimeDist (None, 128, 30, 128)      0
# _________________________________________________________________
# time_distributed_8 (TimeDist (None, 128, 3840)         0
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 128, 512)          8390656
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 128, 512)          0
# _________________________________________________________________
# bidirectional_3 (Bidirection (None, 256)               656384
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 64)                16448
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 3)                 195
# =================================================================
# Total params: 9,165,187
# Trainable params: 9,164,419
# Non-trainable params: 768
# _________________________________________________________________
# None
#
# Epoch 00001: val_loss improved from inf to 1.09489, saving model to ./best_model.hdf5
#
# Epoch 00002: val_loss improved from 1.09489 to 1.02727, saving model to ./best_model.hdf5
#
# Epoch 00003: val_loss improved from 1.02727 to 1.00371, saving model to ./best_model.hdf5
#
# Epoch 00004: val_loss did not improve from 1.00371
#
# Epoch 00005: val_loss did not improve from 1.00371
#
# Epoch 00006: val_loss did not improve from 1.00371
#
# Epoch 00007: val_loss did not improve from 1.00371
#
# Epoch 00008: val_loss did not improve from 1.00371
#
# Epoch 00009: val_loss did not improve from 1.00371
#
# Epoch 00010: val_loss did not improve from 1.00371
#
# Epoch 00011: val_loss did not improve from 1.00371
#
# Epoch 00012: val_loss did not improve from 1.00371
#
# Epoch 00013: val_loss did not improve from 1.00371
#
# Epoch 00014: val_loss did not improve from 1.00371
#
# Epoch 00015: val_loss did not improve from 1.00371
#
# Epoch 00016: val_loss did not improve from 1.00371
#
# Epoch 00017: val_loss did not improve from 1.00371
#
# Epoch 00018: val_loss did not improve from 1.00371
#
# Epoch 00019: val_loss did not improve from 1.00371
#
# Epoch 00020: val_loss did not improve from 1.00371
#
# Epoch 00021: val_loss did not improve from 1.00371
#
# Epoch 00022: val_loss did not improve from 1.00371
#
# Epoch 00023: val_loss did not improve from 1.00371
#
# Epoch 00024: val_loss did not improve from 1.00371
#
# Epoch 00025: val_loss did not improve from 1.00371
#
# Epoch 00026: val_loss did not improve from 1.00371
#
# Epoch 00027: val_loss did not improve from 1.00371
#
# Epoch 00028: val_loss did not improve from 1.00371
#
# Epoch 00029: val_loss did not improve from 1.00371
#
# Epoch 00030: val_loss did not improve from 1.00371
#
# Epoch 00031: val_loss did not improve from 1.00371
#
# Epoch 00032: val_loss did not improve from 1.00371
#
# Epoch 00033: val_loss did not improve from 1.00371
#
# Epoch 00034: val_loss did not improve from 1.00371
#
# Epoch 00035: val_loss did not improve from 1.00371
#
# Epoch 00036: val_loss did not improve from 1.00371
#
# Epoch 00037: val_loss did not improve from 1.00371
#
# Epoch 00038: val_loss did not improve from 1.00371
#
# Epoch 00039: val_loss did not improve from 1.00371
#
# Epoch 00040: val_loss did not improve from 1.00371
#
# Epoch 00041: val_loss did not improve from 1.00371
#
# Epoch 00042: val_loss did not improve from 1.00371
#
# Epoch 00043: val_loss did not improve from 1.00371
#
# Epoch 00044: val_loss did not improve from 1.00371
#
# Epoch 00045: val_loss did not improve from 1.00371
#
# Epoch 00046: val_loss did not improve from 1.00371
#
# Epoch 00047: val_loss did not improve from 1.00371
#
# Epoch 00048: val_loss did not improve from 1.00371
#
# Epoch 00049: val_loss did not improve from 1.00371
#
# Epoch 00050: val_loss did not improve from 1.00371
#
# Epoch 00051: val_loss did not improve from 1.00371
#
# Epoch 00052: val_loss did not improve from 1.00371
#
# Epoch 00053: val_loss did not improve from 1.00371
#
# Epoch 00054: val_loss did not improve from 1.00371
#
# Epoch 00055: val_loss did not improve from 1.00371
#
# Epoch 00056: val_loss did not improve from 1.00371
#
# Epoch 00057: val_loss did not improve from 1.00371
#
# Epoch 00058: val_loss did not improve from 1.00371
#
# Epoch 00059: val_loss did not improve from 1.00371
#
# Epoch 00060: val_loss did not improve from 1.00371
#
# Epoch 00061: val_loss did not improve from 1.00371
#
# Epoch 00062: val_loss did not improve from 1.00371
#
# Epoch 00063: val_loss did not improve from 1.00371
#
# Epoch 00064: val_loss did not improve from 1.00371
#
# Epoch 00065: val_loss did not improve from 1.00371
#
# Epoch 00066: val_loss did not improve from 1.00371
#
# Epoch 00067: val_loss did not improve from 1.00371
#
# Epoch 00068: val_loss did not improve from 1.00371
#
# Epoch 00069: val_loss did not improve from 1.00371
#
# Epoch 00070: val_loss did not improve from 1.00371
#
# Epoch 00071: val_loss did not improve from 1.00371
#
# Epoch 00072: val_loss did not improve from 1.00371
#
# Epoch 00073: val_loss did not improve from 1.00371
#
# Epoch 00074: val_loss did not improve from 1.00371
#
# Epoch 00075: val_loss did not improve from 1.00371
#
# Epoch 00076: val_loss did not improve from 1.00371
#
# Epoch 00077: val_loss did not improve from 1.00371
#
# Epoch 00078: val_loss did not improve from 1.00371
#
# Epoch 00079: val_loss did not improve from 1.00371
#
# Epoch 00080: val_loss did not improve from 1.00371
#
# Epoch 00081: val_loss did not improve from 1.00371
#
# Epoch 00082: val_loss did not improve from 1.00371
#
# Epoch 00083: val_loss did not improve from 1.00371
#
# Epoch 00084: val_loss did not improve from 1.00371
#
# Epoch 00085: val_loss did not improve from 1.00371
#
# Epoch 00086: val_loss did not improve from 1.00371
#
# Epoch 00087: val_loss did not improve from 1.00371
#
# Epoch 00088: val_loss did not improve from 1.00371
#
# Epoch 00089: val_loss did not improve from 1.00371
#
# Epoch 00090: val_loss did not improve from 1.00371
#
# Epoch 00091: val_loss did not improve from 1.00371
#
# Epoch 00092: val_loss did not improve from 1.00371
#
# Epoch 00093: val_loss did not improve from 1.00371
#
# Epoch 00094: val_loss did not improve from 1.00371
#
# Epoch 00095: val_loss did not improve from 1.00371
#
# Epoch 00096: val_loss did not improve from 1.00371
#
# Epoch 00097: val_loss did not improve from 1.00371
#
# Epoch 00098: val_loss did not improve from 1.00371
#
# Epoch 00099: val_loss did not improve from 1.00371
#
# Epoch 00100: val_loss did not improve from 1.00371

# %%
plotHistory(model_5_history)
# Out:
# Max. Validation Accuracy 0.800000011920929

# %%
# evaluation
test_loss, test_acc  = k.models.load_model(bestModelPath).evaluate(X_test, y_test, batch_size=128)
print("The test Loss is :",test_loss)
print("The test Accuracy is :",test_acc*100)
# Out:
# 1/1 [==============================] - 0s 4ms/step - loss: 1.0975 - accuracy: 0.0000e+00
# The test Loss is : 1.0975087881088257
# The test Accuracy is : 0.0

# %% [markdown]
# ## Model using Image Data

# %%
modelPath = './best_model.hdf5'
ACCURACY_THRESHOLD = 0.95

class myCallback(k.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get('val_accuracy') > ACCURACY_THRESHOLD):
            print("\n\nStopping training as we have reached %2.2f%% accuracy!" %(ACCURACY_THRESHOLD*100))   
            self.model.stop_training = True

acc_callback = myCallback()

cbs = [#k.callbacks.ReduceLROnPlateau(patience=3, verbose=1), 
       k.callbacks.ModelCheckpoint(filepath=modelPath, monitor='val_loss', verbose=1, save_best_only=True)]

def trainImgModel(model, epochs, optimizer, vb=1):
    batch_size = 64
    callback = myCallback()
    model.compile(optimizer=optimizer,
                  loss='sparse_categorical_crossentropy',
                  metrics='accuracy'
    )
    return model.fit(X_train_img, y_train, 
                     validation_data=(X_test_img, y_test), epochs=epochs, verbose=vb,
                     batch_size=batch_size, callbacks=cbs)

def plotHistory(history):
    print("Max. Validation Accuracy",max(history.history["val_accuracy"]))
    pd.DataFrame(history.history).plot(figsize=(12,6))
    plt.show()

# %%
model_6 = k.models.Sequential([
    k.layers.Conv2D(256, 3, activation='relu', input_shape=(128, 128, 3)),
    k.layers.BatchNormalization(),
    k.layers.MaxPooling2D(pool_size=(2)),
    k.layers.Dropout(0.2),
    k.layers.Conv2D(128, 3, activation='relu'),
    k.layers.BatchNormalization(),
    k.layers.MaxPooling2D(pool_size=(2)),
    k.layers.Dropout(0.2),
    k.layers.Conv2D(64, 3, padding='same', activation='relu'),
    k.layers.BatchNormalization(),
    k.layers.Flatten(),
    k.layers.Dense(64, activation='relu'),
    k.layers.Dense(len(index_label), activation='softmax'),

])
print(model_6.summary())
model_6_history = trainImgModel(model=model_6, epochs=100, optimizer='rmsprop', vb=0)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 126, 126, 256)     7168
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 126, 126, 256)     1024
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 63, 63, 256)       0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 63, 63, 256)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 61, 61, 128)       295040
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 61, 61, 128)       512
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 30, 30, 128)       0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 30, 30, 128)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 30, 30, 64)        73792
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 30, 30, 64)        256
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 57600)             0
# _________________________________________________________________
# dense_13 (Dense)             (None, 64)                3686464
# _________________________________________________________________
# dense_14 (Dense)             (None, 3)                 195
# =================================================================
# Total params: 4,064,451
# Trainable params: 4,063,555
# Non-trainable params: 896
# _________________________________________________________________
# None
#
# Epoch 00001: val_loss improved from inf to 1.08133, saving model to ./best_model.hdf5
#
# Epoch 00002: val_loss improved from 1.08133 to 1.06285, saving model to ./best_model.hdf5
#
# Epoch 00003: val_loss did not improve from 1.06285
#
# Epoch 00004: val_loss did not improve from 1.06285
#
# Epoch 00005: val_loss did not improve from 1.06285
#
# Epoch 00006: val_loss did not improve from 1.06285
#
# Epoch 00007: val_loss did not improve from 1.06285
#
# Epoch 00008: val_loss did not improve from 1.06285
#
# Epoch 00009: val_loss did not improve from 1.06285
#
# Epoch 00010: val_loss did not improve from 1.06285
#
# Epoch 00011: val_loss did not improve from 1.06285
#
# Epoch 00012: val_loss did not improve from 1.06285
#
# Epoch 00013: val_loss did not improve from 1.06285
#
# Epoch 00014: val_loss did not improve from 1.06285
#
# Epoch 00015: val_loss did not improve from 1.06285
#
# Epoch 00016: val_loss did not improve from 1.06285
#
# Epoch 00017: val_loss did not improve from 1.06285
#
# Epoch 00018: val_loss did not improve from 1.06285
#
# Epoch 00019: val_loss did not improve from 1.06285
#
# Epoch 00020: val_loss did not improve from 1.06285
#
# Epoch 00021: val_loss did not improve from 1.06285
#
# Epoch 00022: val_loss did not improve from 1.06285
#
# Epoch 00023: val_loss did not improve from 1.06285
#
# Epoch 00024: val_loss did not improve from 1.06285
#
# Epoch 00025: val_loss did not improve from 1.06285
#
# Epoch 00026: val_loss did not improve from 1.06285
#
# Epoch 00027: val_loss did not improve from 1.06285
#
# Epoch 00028: val_loss did not improve from 1.06285
#
# Epoch 00029: val_loss did not improve from 1.06285
#
# Epoch 00030: val_loss did not improve from 1.06285
#
# Epoch 00031: val_loss did not improve from 1.06285
#
# Epoch 00032: val_loss did not improve from 1.06285
#
# Epoch 00033: val_loss did not improve from 1.06285
#
# Epoch 00034: val_loss did not improve from 1.06285
#
# Epoch 00035: val_loss did not improve from 1.06285
#
# Epoch 00036: val_loss did not improve from 1.06285
#
# Epoch 00037: val_loss did not improve from 1.06285
#
# Epoch 00038: val_loss did not improve from 1.06285
#
# Epoch 00039: val_loss did not improve from 1.06285
#
# Epoch 00040: val_loss did not improve from 1.06285
#
# Epoch 00041: val_loss did not improve from 1.06285
#
# Epoch 00042: val_loss did not improve from 1.06285
#
# Epoch 00043: val_loss did not improve from 1.06285
#
# Epoch 00044: val_loss did not improve from 1.06285
#
# Epoch 00045: val_loss did not improve from 1.06285
#
# Epoch 00046: val_loss did not improve from 1.06285
#
# Epoch 00047: val_loss did not improve from 1.06285
#
# Epoch 00048: val_loss did not improve from 1.06285
#
# Epoch 00049: val_loss did not improve from 1.06285
#
# Epoch 00050: val_loss did not improve from 1.06285
#
# Epoch 00051: val_loss did not improve from 1.06285
#
# Epoch 00052: val_loss did not improve from 1.06285
#
# Epoch 00053: val_loss did not improve from 1.06285
#
# Epoch 00054: val_loss did not improve from 1.06285
#
# Epoch 00055: val_loss did not improve from 1.06285
#
# Epoch 00056: val_loss did not improve from 1.06285
#
# Epoch 00057: val_loss did not improve from 1.06285
#
# Epoch 00058: val_loss did not improve from 1.06285
#
# Epoch 00059: val_loss did not improve from 1.06285
#
# Epoch 00060: val_loss did not improve from 1.06285
#
# Epoch 00061: val_loss did not improve from 1.06285
#
# Epoch 00062: val_loss did not improve from 1.06285
#
# Epoch 00063: val_loss did not improve from 1.06285
#
# Epoch 00064: val_loss did not improve from 1.06285
#
# Epoch 00065: val_loss did not improve from 1.06285
#
# Epoch 00066: val_loss did not improve from 1.06285
#
# Epoch 00067: val_loss did not improve from 1.06285
#
# Epoch 00068: val_loss did not improve from 1.06285
#
# Epoch 00069: val_loss did not improve from 1.06285
#
# Epoch 00070: val_loss did not improve from 1.06285
#
# Epoch 00071: val_loss did not improve from 1.06285
#
# Epoch 00072: val_loss did not improve from 1.06285
#
# Epoch 00073: val_loss did not improve from 1.06285
#
# Epoch 00074: val_loss did not improve from 1.06285
#
# Epoch 00075: val_loss did not improve from 1.06285
#
# Epoch 00076: val_loss did not improve from 1.06285
#
# Epoch 00077: val_loss did not improve from 1.06285
#
# Epoch 00078: val_loss did not improve from 1.06285
#
# Epoch 00079: val_loss did not improve from 1.06285
#
# Epoch 00080: val_loss did not improve from 1.06285
#
# Epoch 00081: val_loss did not improve from 1.06285
#
# Epoch 00082: val_loss did not improve from 1.06285
#
# Epoch 00083: val_loss did not improve from 1.06285
#
# Epoch 00084: val_loss did not improve from 1.06285
#
# Epoch 00085: val_loss did not improve from 1.06285
#
# Epoch 00086: val_loss did not improve from 1.06285
#
# Epoch 00087: val_loss did not improve from 1.06285
#
# Epoch 00088: val_loss did not improve from 1.06285
#
# Epoch 00089: val_loss did not improve from 1.06285
#
# Epoch 00090: val_loss did not improve from 1.06285
#
# Epoch 00091: val_loss did not improve from 1.06285
#
# Epoch 00092: val_loss did not improve from 1.06285
#
# Epoch 00093: val_loss did not improve from 1.06285
#
# Epoch 00094: val_loss did not improve from 1.06285
#
# Epoch 00095: val_loss did not improve from 1.06285
#
# Epoch 00096: val_loss did not improve from 1.06285
#
# Epoch 00097: val_loss did not improve from 1.06285
#
# Epoch 00098: val_loss did not improve from 1.06285
#
# Epoch 00099: val_loss did not improve from 1.06285
#
# Epoch 00100: val_loss did not improve from 1.06285

# %%
plotHistory(model_6_history)
# Out:
# Max. Validation Accuracy 0.4399999976158142

# %%
# model evaluation
test_loss, test_acc  = k.models.load_model(bestModelPath).evaluate(X_test_img, y_test, batch_size=128)
print("The test Loss is :",test_loss)
print("The test Accuracy is :",test_acc*100)
# Out:
# 1/1 [==============================] - 0s 4ms/step - loss: 1.0628 - accuracy: 0.0000e+00
# The test Loss is : 1.0628464221954346
# The test Accuracy is : 0.0

# %%
# test_data = np.expand_dims(test_data, axis=3)

# %%
predictions = np.argmax(k.models.load_model(bestModelPath).predict(test_data_img), axis=1)
predictions
# Out:
# array([2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 1, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 1,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        0, 0, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2])

# %%
df_sub = pd.DataFrame({
    'Filename': test_files,
    'Class': list(map(lambda x:index_label[x], predictions))
})
df_sub.head()
# Out:
#   Filename     Class
# 0  112.wav  Positive
# 1  113.wav  Positive
# 2  115.wav  Positive
# 3  119.wav  Positive
# 4  123.wav   Neutral

# %%
submission_file = 'submission.csv'
df_sub.to_csv(submission_file, index=False)
